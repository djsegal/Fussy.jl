# %%
Pkg.add("Tokamak")
Pkg.add("PyPlot")

using Tokamak
using PyPlot
# Out:
# INFO: Nothing to be done
# INFO: Nothing to be done
# WARNING: using DefaultSymbols.cd in module Tokamak conflicts with an existing identifier.
# WARNING: imported binding for cd overwritten in module Tokamak

# %%
Tokamak.load_input("input.jl", true)

solved_eqs = Tokamak.sweep_T_k(10:15);
# Out:
# beta
#
# R_0 =
# Any[0.807915,1.24579,1.89512,2.85459,4.26878,6.34936]
# B_0 =
# Any[28.7379,20.5007,14.7016,10.5735,7.61456,5.48506]
# other_limits =
# beta: Any[1.50039084470791,1.36399167700719,1.25032570392326,1.15414680362147,1.07170774621994,1.00026056313861]
# wall: Any[11.1958048636583,5.06195489333567,2.30788381438119,1.05620090947810,0.483724126779513,0.221264423620748]
# heat: Any[7.56876921629871,2.88282265459687,1.13088973889581,0.453568440776989,0.184986607036454,0.0764164421832077]
#
# wall
#
# R_0 =
# Any[1.80677,2.1383,2.50357,2.9061,3.34981,3.839]
# B_0 =
# Any[67.81,36.4783,19.7856,10.7771,5.87953,3.20703]
# other_limits =
# beta: Any[0.284334549199463,0.446603859004325,0.703261581617245,1.11226970823479,1.76872884283998,2.82946323281730]
# wall: Any[1.00102927956198,1.00102927956200,1.00102927956198,1.00102927956199,1.00102927956199,1.00102927956198]
# heat: Any[0.576115403858049,0.511707367501770,0.463947271865973,0.428341107378127,0.401833296425474,0.382317651375301]
#
# heat
#
# R_0 =
# Any[1.04321,1.30325,1.60956,1.96975,2.39272,2.88877]
# B_0 =
# Any[37.7453,21.5109,12.3511,7.11777,4.1065,2.3679]
# other_limits =
# beta: Any[0.884686056662537,1.24261432652126,1.75231899533168,2.48467776735790,3.54537143752333,5.09269765329508]
# wall: Any[5.20035776570361,4.42143974068940,3.76708908382102,3.21474647406996,2.74684769292271,2.34942740363408]
# heat: Any[3.34042474458171,2.49543576493014,1.90720924196394,1.48685870481704,1.17939578725222,0.949818481343470]

# %%
beta_solution = solved_eqs["beta"]
plot(beta_solution["B_0"],beta_solution["R_0"])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32dadd3d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x32d90f350>
